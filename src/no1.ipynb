# %%
import pandas as pd

# col_names = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality' ]
df = pd.read_csv('../data/anggur.csv')
df = df.drop([0])
df
# def nomor1(col_names):
#     col_names = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality' ]
#     df = pd.read_csv('../data/anggur.csv', names = col_names)
#     df1 = df[col_names]
#     dic = {'mean':df1.mean(),'median':df1.median(),'modus':df1.mode().values,
#           'standar deviasi':df1.std(), 'variansi':df1.var(),
#            'range':df1.max()-df1.min(), 'minimum':df1.min(), 
#            'maksimum':df1.max(),'kuartil 1':df1.quantile(0.25),
#            'kuartil 2':df1.quantile(0.5),'kuartil 3':df1.quantile(0.75), 
#            'IQR':df1.quantile(0.75) - df1.quantile(0.25), 'skewness':df1.skew(),
#            'kurtosis':df1.kurtosis()
#           }
#     dic_list = list(dic.items())

#     new_df = pd.DataFrame.from_dict(dic_list)
#     return new_df.style.set_table_attributes("style='display:inline'").set_caption('Deskripsi Statistik '+col_names)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1             8.40            0.5768       0.2099        3.109590   0.101681
# 2             7.54            0.5918       0.3248        3.673744   0.072416
# 3             5.39            0.4201       0.3131        3.371815   0.072755
# 4             6.51            0.5675       0.1940        4.404723   0.066379
# 5             9.18            0.3332       0.2476        2.633491   0.082304
# ..             ...               ...          ...             ...        ...
# 995           7.96            0.6046       0.2662        1.592048   0.057555
# 996           8.48            0.4080       0.2227        0.681955   0.051627
# 997           6.11            0.4841       0.3720        2.377267   0.042806
# 998           7.76            0.3590       0.3208        4.294486   0.098276
# 999           5.87            0.5214       0.1883        2.179490   0.052923
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     999.000000        999.000000   999.000000      999.000000
# mean        7.153784          0.520914     0.270606        2.567622
# std         1.201545          0.095866     0.049042        0.988274
# min         3.320000          0.139900     0.116700        0.032555
# 25%         6.380000          0.456300     0.237800        1.896296
# 50%         7.150000          0.525000     0.272300        2.520993
# 75%         8.000000          0.585550     0.302450        3.221676
# max        11.490000          0.805100     0.409600        5.550755
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  999.000000           999.000000            999.000000  999.000000
# mean     0.081206            14.905991             40.288168    0.995923
# std      0.020118             4.890256              9.970562    0.002020
# ...

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

def get_descriptive_statistics(column):
    mean = np.mean(column)
    median = np.median(column)
    mode = stats.mode(column)
    std_dev = np.std(column)
    variance = np.var(column)
    data_range = np.ptp(column)
    minimum = np.min(column)
    maximum = np.max(column)
    quartile1 = np.quantile(column, 0.25)
    quartile2 = np.quantile(column, 0.5)
    quartile3 = np.quantile(column, 0.75)
    iqr = stats.iqr(column)
    skewness = stats.skew(column)
    kurtosis = stats.kurtosis(column)
    
    return pd.DataFrame({
        'mean': mean,
        'median': median,
        'mode': mode.mode,
        'standard deviation': std_dev,
        'variance': variance,
        'range': data_range,
        'minimum': minimum,
        'maximum': maximum,
        'Q1': quartile1,
        'Q2': quartile2,
        'Q3': quartile3,
        'IQR': iqr,
        'skewness': skewness,
        'kurtosis': kurtosis
    })

def describe_column(column_name):
    df = pd.read_csv('../data/anggur.csv')
    column = df[column_name]
    descriptive_statistics = get_descriptive_statistics(column)
    return descriptive_statistics.style.format("{:.2f}")

# %% [markdown]
# Deskripsi Statistika Kolom Fixed Acidity

# %%
describe_column('fixed acidity')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_33380_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# Deskripsi Statistika Kolom volatile acidity

# %%
describe_column('volatile acidity')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_6c612_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# Deskripsi Statistika Kolom Citric Acid

# %%
describe_column('citric acid')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_09b68_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# deskripsi statistika kolom residual sugar

# %%
describe_column('residual sugar')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_ef103_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# deskripsi statistika kolom chlorides

# %%
describe_column('chlorides')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_8e6a5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# deskripsi statistika kolom free sulfur dioxide

# %%
describe_column('free sulfur dioxide')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_b3938_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# deskripsi statistika kolom total sulfur dioxide

# %%
describe_column('total sulfur dioxide')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_b43f0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# deskripsi statistika kolom density

# %%
describe_column('density')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_fd0a6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# deskripsi statistika kolom pH

# %%
describe_column('pH')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_dc01e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# deskripsi statistika kolom sulphates

# %%
describe_column('sulphates')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_3054b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...

# %% [markdown]
# deskripsi statistika kolom alcohol

# %%
describe_column('alcohol')
# Out:
# C:\Users\syauq\AppData\Local\Temp\ipykernel_18064\724051637.py:8: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(column)
# <style type="text/css">
# </style>
# <table id="T_3a223_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >mode</th>
#       <th class="col_heading level0 col3" >standard deviation</th>
#       <th class="col_heading level0 col4" >variance</th>
#       <th class="col_heading level0 col5" >range</th>
# ...
